# %% [markdown]
# 2. For a given dataset predict number of bikes getting shared based on
# different parameters

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing dataset

# %%
dataset=pd.read_csv("bike_sharing.csv")

# %%
dataset.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
dataset.shape
# Out:
# (17379, 17)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
dataset.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ## Data cleaning

# %%
dataset=dataset.drop(columns=['instant','dteday'])

# %% [markdown]
# ### Checking for null values

# %%
dataset.isna().sum()
# Out:
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ### Checking for duplicates

# %%
dataset.duplicated().sum()
# Out:
# 2

# %%
dataset.head()
# Out:
#    season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0       1   0     1   0        0        6           0           1  0.24
# 1       1   0     1   1        0        6           0           1  0.22
# 2       1   0     1   2        0        6           0           1  0.22
# 3       1   0     1   3        0        6           0           1  0.24
# 4       1   0     1   4        0        6           0           1  0.24
#
#     atemp   hum  windspeed  casual  registered  cnt
# 0  0.2879  0.81        0.0       3          13   16
# 1  0.2727  0.80        0.0       8          32   40
# 2  0.2727  0.80        0.0       5          27   32
# 3  0.2879  0.75        0.0       3          10   13
# 4  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Checking for multicolinearity

# %%
corrmatrix=dataset.iloc[:,:-1].corr()

# %%
sns.heatmap(corrmatrix)
# Out:
# <AxesSubplot:>

# %%
def correlation(dataset,threshold,corrmatrix):
    correlated_col=set()
    for i in range(len(corrmatrix.columns)):
        for j in range(i):
            if abs(corrmatrix.iloc[i,j])>=threshold:
                correlated_col.add(corrmatrix.columns[i])
    return correlated_col

# %%
threshold=0.6
corelatedcols=correlation(dataset,threshold,corrmatrix)
corelatedcols
# Out:
# {'atemp', 'mnth'}

# %% [markdown]
# ### Drop multicolinear columns

# %%
dataset=dataset.drop(columns=corelatedcols)

# %%
col=dataset.columns

# %% [markdown]
# ## Feature scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
dataset=sc.fit_transform(dataset)

# %%
dataset=pd.DataFrame(dataset,columns=col)

# %% [markdown]
# ### Checking for outlier

# %%
plt.figure(figsize=(20,10))
dataset.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Handling outlier

# %%
for i in dataset.columns:
    percentiles = dataset[i].quantile([0.25,0.75]).values
    dataset[i][dataset[i] <= percentiles[0]] = percentiles[0]
    dataset[i][dataset[i] >= percentiles[1]] = percentiles[1]

# %%
plt.figure(figsize=(20,10))
dataset.boxplot()
# Out:
# <AxesSubplot:>

# %%
dataset.shape
# Out:
# (17379, 13)

# %%
x=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1].values
y=y.reshape(-1,1)

# %% [markdown]
# ## Data train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((13034, 12), (4345, 12), (13034, 1), (4345, 1))

# %% [markdown]
# ## Model building

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree

# %%
dr=DecisionTreeRegressor(max_depth=9)

# %%
dr.fit(x_train,y_train)
y_train_pred=dr.predict(x_train)

# %%
r2=r2_score(y_train,y_train_pred)
r2
# Out:
# 0.9969585093313922

# %%
Mean_Squared_Error=mean_squared_error(y_train,y_train_pred)
Mean_Squared_Error
# Out:
# 0.0008880685275793363

# %%
plt.figure(figsize=(15,15))
tree.plot_tree(dr,filled=True)
# Out:
# [Text(0.48011057173678534, 0.95, 'X[11] <= -0.194\nsquared_error = 0.292\nsamples = 13034\nvalue = -0.196'),
#  Text(0.21703074433656958, 0.85, 'X[11] <= -0.557\nsquared_error = 0.047\nsamples = 6828\nvalue = -0.661'),
#  Text(0.09641316073354908, 0.75, 'X[11] <= -0.722\nsquared_error = 0.005\nsamples = 4701\nvalue = -0.787'),
#  Text(0.05076860841423948, 0.65, 'X[10] <= -0.075\nsquared_error = 0.0\nsamples = 3705\nvalue = -0.819'),
#  Text(0.03168824163969795, 0.55, 'X[11] <= -0.775\nsquared_error = 0.0\nsamples = 3694\nvalue = -0.82'),
#  Text(0.015911542610571736, 0.45, 'X[10] <= -0.45\nsquared_error = 0.0\nsamples = 3364\nvalue = -0.823'),
#  Text(0.008629989212513484, 0.35, 'X[10] <= -0.511\nsquared_error = 0.0\nsamples = 3284\nvalue = -0.824'),
#  Text(0.004314994606256742, 0.25, 'X[11] <= -0.782\nsquared_error = 0.0\nsamples = 3180\nvalue = -0.824'),
#  Text(0.002157497303128371, 0.15, 'X[10] <= -0.551\nsquared_error = 0.0\nsamples = 3142\nvalue = -0.824'),
#  Text(0.0010787486515641855, 0.05, 'squared_error = 0.0\nsamples = 3044\nvalue = -0.824'),
#  Text(0.003236245954692557, 0.05, 'squared_error = 0.0\nsamples = 98\nvalue = -0.822'),
#  Text(0.006472491909385114, 0.15, 'X[10] <= -0.612\nsquared_error = 0.0\nsamples = 38\nvalue = -0.817'),
#  Text(0.005393743257820928, 0.05, 'squared_error = 0.0\nsamples = 24\nvalue = -0.824'),
#  Text(0.007551240560949299, 0.05, 'squared_error = 0.0\nsamples = 14\nvalue = -0.806'),
#  Text(0.012944983818770227, 0.25, 'X[11] <= -0.788\nsquared_error = 0.0\nsamples = 104\nvalue = -0.815'),
#  Text(0.010787486515641856, 0.15, 'X[2] <= -0.585\nsquared_error = 0.0\nsamples = 96\nvalue = -0.818'),
#  Text(0.009708737864077669, 0.05, 'squared_error = 0.0\nsamples = 74\nvalue = -0.82'),
#  Text(0.011866235167206042, 0.05, 'squared_error = 0.0\nsamples = 22\nvalue = -0.812'),
#  Text(0.015102481121898598, 0.15, 'X[9] <= 0.398\nsquared_error = 0.0\nsamples = 8\nvalue = -0.785'),
#  Text(0.014023732470334413, 0.05, 'squared_error = 0.0\nsamples = 6\nvalue = -0.784'),
#  Text(0.016181229773462782, 0.05, 'squared_error = -0.0\nsamples = 2\nvalue = -0.791'),
#  Text(0.02319309600862999, 0.35, 'X[10] <= -0.348\nsquared_error = 0.001\nsamples = 80\nvalue = -0.799'),
#  Text(0.020496224379719527, 0.25, 'X[11] <= -0.788\nsquared_error = 0.0\nsamples = 60\nvalue = -0.806'),
#  Text(0.019417475728155338, 0.15, 'X[1] <= -0.005\nsquared_error = 0.0\nsamples = 58\nvalue = -0.807'),
#  Text(0.018338727076591153, 0.05, 'squared_error = 0.0\nsamples = 35\nvalue = -0.811'),
#  Text(0.020496224379719527, 0.05, 'squared_error = 0.0\nsamples = 23\nvalue = -0.801'),
#  Text(0.021574973031283712, 0.15, 'squared_error = -0.0\nsamples = 2\nvalue = -0.763'),
#  Text(0.025889967637540454, 0.25, 'X[6] <= 0.117\nsquared_error = 0.001\nsamples = 20\nvalue = -0.78'),
#  Text(0.023732470334412083, 0.15, 'X[5] <= -0.393\nsquared_error = 0.001\nsamples = 18\nvalue = -0.777'),
#  Text(0.022653721682847898, 0.05, 'squared_error = 0.0\nsamples = 12\nvalue = -0.767'),
#  Text(0.02481121898597627, 0.05, 'squared_error = 0.001\nsamples = 6\nvalue = -0.796'),
#  Text(0.028047464940668825, 0.15, 'X[4] <= -0.75\nsquared_error = 0.0\nsamples = 2\nvalue = -0.813'),
#  Text(0.02696871628910464, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = -0.819'),
#  Text(0.02912621359223301, 0.05, 'squared_error = -0.0\nsamples = 1\nvalue = -0.807'),
#  Text(0.04746494066882417, 0.45, 'X[10] <= -0.571\nsquared_error = 0.001\nsamples = 330\nvalue = -0.786'),
#  Text(0.038834951456310676, 0.35, 'X[11] <= -0.742\nsquared_error = 0.0\nsamples = 222\nvalue = -0.803'),
#  Text(0.034519956850053934, 0.25, 'X[10] <= -0.632\nsquared_error = 0.0\nsamples = 141\nvalue = -0.812'),
#  Text(0.032362459546925564, 0.15, 'X[11] <= -0.755\nsquared_error = 0.0\nsamples = 100\nvalue = -0.817'),
#  Text(0.03128371089536138, 0.05, 'squared_error = 0.0\nsamples = 61\nvalue = -0.821'),
#  Text(0.03344120819848975, 0.05, 'squared_error = 0.0\nsamples = 39\nvalue = -0.812'),
#  Text(0.036677454153182305, 0.15, 'X[11] <= -0.768\nsquared_error = 0.0\nsamples = 41\nvalue = -0.797'),
#  Text(0.03559870550161812, 0.05, 'squared_error = 0.0\nsamples = 8\nvalue = -0.81'),
#  Text(0.037756202804746494, 0.05, 'squared_error = 0.0\nsamples = 33\nvalue = -0.794'),
#  Text(0.043149946062567425, 0.25, 'X[10] <= -0.632\nsquared_error = 0.0\nsamples = 81\nvalue = -0.788'),
#  Text(0.040992448759439054, 0.15, 'X[11] <= -0.735\nsquared_error = 0.0\nsamples = 59\nvalue = -0.794'),
#  Text(0.039913700107874865, 0.05, 'squared_error = 0.0\nsamples = 16\nvalue = -0.802'),
#  Text(0.042071197411003236, 0.05, 'squared_error = 0.0\nsamples = 43\nvalue = -0.792'),
#  Text(0.045307443365695796, 0.15, 'X[11] <= -0.735\nsquared_error = 0.0\nsamples = 22\nvalue = -0.771'),
#  Text(0.04422869471413161, 0.05, 'squared_error = 0.0\nsamples = 5\nvalue = -0.779'),
#  Text(0.04638619201725998, 0.05, 'squared_error = 0.0\nsamples = 17\nvalue = -0.769'),
#  Text(0.05609492988133765, 0.35, 'X[10] <= -0.43\nsquared_error = 0.001\nsamples = 108\nvalue = -0.75'),
#  Text(0.05177993527508091, 0.25, 'X[11] <= -0.755\nsquared_error = 0.0\nsamples = 77\nvalue = -0.763'),
#  Text(0.04962243797195254, 0.15, 'X[10] <= -0.531\nsquared_error = 0.0\nsamples = 27\nvalue = -0.778'),
#  Text(0.04854368932038835, 0.05, 'squared_error = 0.0\nsamples = 11\nvalue = -0.786'),
#  Text(0.05070118662351672, 0.05, 'squared_error = 0.0\nsamples = 16\nvalue = -0.772'),
#  Text(0.05393743257820928, 0.15, 'X[10] <= -0.511\nsquared_error = 0.0\nsamples = 50\nvalue = -0.754'),
#  Text(0.05285868392664509, 0.05, 'squared_error = 0.0\nsamples = 26\nvalue = -0.762'),
#  Text(0.05501618122977346, 0.05, 'squared_error = 0.0\nsamples = 24\nvalue = -0.746'),
#  Text(0.06040992448759439, 0.25, 'X[10] <= -0.308\nsquared_error = 0.001\nsamples = 31\nvalue = -0.719'),
#  Text(0.05825242718446602, 0.15, 'X[11] <= -0.755\nsquared_error = 0.0\nsamples = 24\nvalue = -0.729'),
#  Text(0.05717367853290183, 0.05, 'squared_error = 0.0\nsamples = 11\nvalue = -0.742'),
#  Text(0.0593311758360302, 0.05, 'squared_error = 0.0\nsamples = 13\nvalue = -0.718'),
#  Text(0.06256742179072276, 0.15, 'X[7] <= 0.587\nsquared_error = 0.0\nsamples = 7\nvalue = -0.685'),
#  Text(0.061488673139158574, 0.05, 'squared_error = 0.0\nsamples = 4\nvalue = -0.692'),
#  Text(0.06364617044228695, 0.05, 'squared_error = 0.0\nsamples = 3\nvalue = -0.677'),
#  Text(0.06984897518878101, 0.55, 'X[1] <= -0.005\nsquared_error = 0.005\nsamples = 11\nvalue = -0.592'),
#  Text(0.06634304207119741, 0.45, 'X[11] <= -0.772\nsquared_error = 0.001\nsamples = 8\nvalue = -0.629'),
#  Text(0.06364617044228695, 0.35, 'X[10] <= -0.034\nsquared_error = 0.0\nsamples = 2\nvalue = -0.675'),
#  Text(0.06256742179072276, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = -0.697'),
#  Text(0.06472491909385113, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = -0.653'),
#  Text(0.06903991370010787, 0.35, 'X[10] <= 0.037\nsquared_error = 0.0\nsamples = 6\nvalue = -0.614'),
#  Text(0.0668824163969795, 0.25, 'X[10] <= -0.024\nsquared_error = 0.0\nsamples = 3\nvalue = -0.631'),
#  Text(0.06580366774541532, 0.15, 'squared_error = 0.0\nsamples = 1\nvalue = -0.637'),
#  Text(0.06796116504854369, 0.15, 'X[11] <= -0.755\nsquared_error = 0.0\nsamples = 2\nvalue = -0.628'),
#  Text(0.0668824163969795, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = -0.631'),
#  Text(0.06903991370010787, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = -0.626'),
#  Text(0.07119741100323625, 0.25, 'X[9] <= 0.032\nsquared_error = 0.0\nsamples = 3\nvalue = -0.596'),
#  Text(0.07011866235167206, 0.15, 'squared_error = 0.0\nsamples = 1\nvalue = -0.576'),
#  Text(0.07227615965480043, 0.15, 'X[11] <= -0.748\nsquared_error = 0.0\nsamples = 2\nvalue = -0.606'),
#  Text(0.07119741100323625, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = -0.609'),
#  Text(0.07335490830636461, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = -0.603'),
#  Text(0.07335490830636461, 0.45, 'X[7] <= -0.504\nsquared_error = 0.003\nsamples = 3\nvalue = -0.495'),
#  Text(0.07227615965480043, 0.35, 'squared_error = 0.0\nsamples = 1\nvalue = -0.57'),
#  Text(0.0744336569579288, 0.35, 'X[8] <= 0.014\nsquared_error = 0.0\nsamples = 2\nvalue = -0.457'),
#  Text(0.07335490830636461, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = -0.444'),
#  Text(0.07551240560949299, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = -0.471'),
#  Text(0.1420577130528587, 0.65, 'X[10] <= -0.308\nsquared_error = 0.005\nsamples = 996\nvalue = -0.669'),
#  Text(0.10895361380798274, 0.55, 'X[11] <= -0.649\nsquared_error = 0.002\nsamples = 838\nvalue = -0.692'),
#  Text(0.09169363538295577, 0.45, 'X[10] <= -0.571\nsquared_error = 0.001\nsamples = 419\nvalue = -0.727'),
#  Text(0.08306364617044229, 0.35, 'X[11] <= -0.689\nsquared_error = 0.0\nsamples = 232\nvalue = -0.751'),
#  Text(0.07874865156418555, 0.25, 'X[10] <= -0.632\nsquared_error = 0.0\nsamples = 118\nvalue = -0.765'),
#  Text(0.07659115426105717, 0.15, 'X[11] <= -0.709\nsquared_error = 0.0\nsamples = 75\nvalue = -0.773'),
#  Text(0.07551240560949299, 0.05, 'squared_error = 0.0\nsamples = 25\nvalue = -0.784'),
#  Text(0.07766990291262135, 0.05, 'squared_error = 0.0\nsamples = 50\nvalue = -0.767'),
#  Text(0.08090614886731391, 0.15, 'X[11] <= -0.702\nsquared_error = 0.0\nsamples = 43\nvalue = -0.751'),
#  Text(0.07982740021574973, 0.05, 'squared_error = 0.0\nsamples = 23\nvalue = -0.758'),
#  Text(0.08198489751887811, 0.05, 'squared_error = 0.0\nsamples = 20\nvalue = -0.743'),
#  Text(0.08737864077669903, 0.25, 'X[10] <= -0.632\nsquared_error = 0.0\nsamples = 114\nvalue = -0.736'),
#  Text(0.08522114347357065, 0.15, 'X[11] <= -0.669\nsquared_error = 0.0\nsamples = 73\nvalue = -0.742'),
#  Text(0.08414239482200647, 0.05, 'squared_error = 0.0\nsamples = 34\nvalue = -0.751'),
#  Text(0.08629989212513485, 0.05, 'squared_error = 0.0\nsamples = 39\nvalue = -0.734'),
#  Text(0.0895361380798274, 0.15, 'X[11] <= -0.676\nsquared_error = 0.0\nsamples = 41\nvalue = -0.725'),
#  Text(0.08845738942826321, 0.05, 'squared_error = 0.0\nsamples = 17\nvalue = -0.735'),
#  Text(0.09061488673139159, 0.05, 'squared_error = 0.0\nsamples = 24\nvalue = -0.717'),
#  Text(0.10032362459546926, 0.35, 'X[10] <= -0.47\nsquared_error = 0.001\nsamples = 187\nvalue = -0.697'),
#  Text(0.09600862998921252, 0.25, 'X[11] <= -0.682\nsquared_error = 0.0\nsamples = 98\nvalue = -0.715'),
#  Text(0.09385113268608414, 0.15, 'X[11] <= -0.702\nsquared_error = 0.0\nsamples = 54\nvalue = -0.727'),
#  Text(0.09277238403451996, 0.05, 'squared_error = 0.0\nsamples = 25\nvalue = -0.735'),
#  Text(0.09492988133764833, 0.05, 'squared_error = 0.0\nsamples = 29\nvalue = -0.72'),
#  Text(0.09816612729234088, 0.15, 'X[10] <= -0.531\nsquared_error = 0.0\nsamples = 44\nvalue = -0.7'),
#  Text(0.0970873786407767, 0.05, 'squared_error = 0.0\nsamples = 20\nvalue = -0.706'),
#  Text(0.09924487594390508, 0.05, 'squared_error = 0.0\nsamples = 24\nvalue = -0.694'),
#  Text(0.104638619201726, 0.25, 'X[11] <= -0.689\nsquared_error = 0.0\nsamples = 89\nvalue = -0.678'),
#  Text(0.10248112189859762, 0.15, 'X[10] <= -0.369\nsquared_error = 0.0\nsamples = 34\nvalue = -0.696'),
#  Text(0.10140237324703344, 0.05, 'squared_error = 0.0\nsamples = 24\nvalue = -0.703'),
#  Text(0.10355987055016182, 0.05, 'squared_error = 0.0\nsamples = 10\nvalue = -0.679'),
#  Text(0.10679611650485436, 0.15, 'X[10] <= -0.369\nsquared_error = 0.0\nsamples = 55\nvalue = -0.667'),
#  Text(0.10571736785329018, 0.05, 'squared_error = 0.0\nsamples = 40\nvalue = -0.672'),
#  Text(0.10787486515641856, 0.05, 'squared_error = 0.0\nsamples = 15\nvalue = -0.653'),
#  Text(0.1262135922330097, 0.45, 'X[10] <= -0.551\nsquared_error = 0.001\nsamples = 419\nvalue = -0.657'),
#  Text(0.11758360302049622, 0.35, 'X[11] <= -0.603\nsquared_error = 0.001\nsamples = 243\nvalue = -0.679'),
#  Text(0.11326860841423948, 0.25, 'X[10] <= -0.632\nsquared_error = 0.0\nsamples = 135\nvalue = -0.694'),
#  Text(0.1111111111111111, 0.15, 'X[11] <= -0.63\nsquared_error = 0.0\nsamples = 64\nvalue = -0.706'),
#  Text(0.11003236245954692, 0.05, 'squared_error = 0.0\nsamples = 27\nvalue = -0.718'),
#  Text(0.1121898597626753, 0.05, 'squared_error = 0.0\nsamples = 37\nvalue = -0.697'),
#  Text(0.11542610571736785, 0.15, 'X[11] <= -0.623\nsquared_error = 0.0\nsamples = 71\nvalue = -0.684'),
#  Text(0.11434735706580366, 0.05, 'squared_error = 0.0\nsamples = 42\nvalue = -0.691'),
#  Text(0.11650485436893204, 0.05, 'squared_error = 0.0\nsamples = 29\nvalue = -0.673'),
#  Text(0.12189859762675297, 0.25, 'X[10] <= -0.632\nsquared_error = 0.0\nsamples = 108\nvalue = -0.659'),
#  Text(0.11974110032362459, 0.15, 'X[11] <= -0.59\nsquared_error = 0.0\nsamples = 55\nvalue = -0.67'),
#  Text(0.1186623516720604, 0.05, 'squared_error = 0.0\nsamples = 21\nvalue = -0.685'),
#  Text(0.12081984897518878, 0.05, 'squared_error = 0.0\nsamples = 34\nvalue = -0.661'),
#  Text(0.12405609492988134, 0.15, 'X[11] <= -0.583\nsquared_error = 0.0\nsamples = 53\nvalue = -0.648'),
#  Text(0.12297734627831715, 0.05, 'squared_error = 0.0\nsamples = 30\nvalue = -0.657'),
#  Text(0.12513484358144553, 0.05, 'squared_error = 0.0\nsamples = 23\nvalue = -0.636'),
#  Text(0.1348435814455232, 0.35, 'X[11] <= -0.597\nsquared_error = 0.001\nsamples = 176\nvalue = -0.628'),
#  Text(0.13052858683926646, 0.25, 'X[10] <= -0.43\nsquared_error = 0.0\nsamples = 103\nvalue = -0.643'),
#  Text(0.12837108953613807, 0.15, 'X[11] <= -0.623\nsquared_error = 0.0\nsamples = 61\nvalue = -0.657'),
#  Text(0.1272923408845739, 0.05, 'squared_error = 0.0\nsamples = 30\nvalue = -0.668'),
#  Text(0.12944983818770225, 0.05, 'squared_error = 0.0\nsamples = 31\nvalue = -0.647'),
#  Text(0.13268608414239483, 0.15, 'X[11] <= -0.616\nsquared_error = 0.0\nsamples = 42\nvalue = -0.622'),
#  Text(0.13160733549083065, 0.05, 'squared_error = 0.0\nsamples = 26\nvalue = -0.629'),
#  Text(0.133764832793959, 0.05, 'squared_error = 0.0\nsamples = 16\nvalue = -0.61'),
#  Text(0.13915857605177995, 0.25, 'X[10] <= -0.43\nsquared_error = 0.0\nsamples = 73\nvalue = -0.607'),
#  Text(0.13700107874865156, 0.15, 'X[11] <= -0.583\nsquared_error = 0.0\nsamples = 48\nvalue = -0.619'),
#  Text(0.13592233009708737, 0.05, 'squared_error = 0.0\nsamples = 19\nvalue = -0.629'),
#  Text(0.13807982740021574, 0.05, 'squared_error = 0.0\nsamples = 29\nvalue = -0.612'),
#  Text(0.1413160733549083, 0.15, 'X[11] <= -0.583\nsquared_error = 0.0\nsamples = 25\nvalue = -0.585'),
#  Text(0.14023732470334413, 0.05, 'squared_error = 0.0\nsamples = 9\nvalue = -0.595'),
#  Text(0.1423948220064725, 0.05, 'squared_error = 0.0\nsamples = 16\nvalue = -0.58'),
#  Text(0.17516181229773461, 0.55, 'X[10] <= 0.017\nsquared_error = 0.004\nsamples = 158\nvalue = -0.549'),
#  Text(0.16073354908306364, 0.45, 'X[11] <= -0.636\nsquared_error = 0.002\nsamples = 131\nvalue = -0.57'),
#  Text(0.15210355987055016, 0.35, 'X[10] <= -0.166\nsquared_error = 0.001\nsamples = 45\nvalue = -0.617'),
#  Text(0.14778856526429343, 0.25, 'X[11] <= -0.682\nsquared_error = 0.001\nsamples = 32\nvalue = -0.631'),
#  Text(0.14563106796116504, 0.15, 'X[10] <= -0.186\nsquared_error = 0.0\nsamples = 12\nvalue = -0.657'),
#  Text(0.14455231930960086, 0.05, 'squared_error = 0.0\nsamples = 10\nvalue = -0.661'),
#  Text(0.14670981661272922, 0.05, 'squared_error = 0.0\nsamples = 2\nvalue = -0.637'),
#  Text(0.1499460625674218, 0.15, 'X[10] <= -0.206\nsquared_error = 0.0\nsamples = 20\nvalue = -0.616'),
#  Text(0.1488673139158576, 0.05, 'squared_error = 0.0\nsamples = 15\nvalue = -0.619'),
#  Text(0.15102481121898598, 0.05, 'squared_error = 0.0\nsamples = 5\nvalue = -0.605'),
#  Text(0.15641855447680691, 0.25, 'X[11] <= -0.666\nsquared_error = 0.0\nsamples = 13\nvalue = -0.582'),
#  Text(0.15426105717367852, 0.15, 'X[0] <= -0.001\nsquared_error = 0.0\nsamples = 5\nvalue = -0.599'),
#  Text(0.15318230852211434, 0.05, 'squared_error = 0.0\nsamples = 3\nvalue = -0.592'),
#  Text(0.1553398058252427, 0.05, 'squared_error = 0.0\nsamples = 2\nvalue = -0.609'),
#  Text(0.15857605177993528, 0.15, 'X[10] <= -0.044\nsquared_error = 0.0\nsamples = 8\nvalue = -0.571'),
#  Text(0.1574973031283711, 0.05, 'squared_error = 0.0\nsamples = 6\nvalue = -0.579'),
#  Text(0.15965480043149946, 0.05, 'squared_error = 0.0\nsamples = 2\nvalue = -0.548'),
#  Text(0.16936353829557713, 0.35, 'X[10] <= -0.166\nsquared_error = 0.001\nsamples = 86\nvalue = -0.545'),
#  Text(0.1650485436893204, 0.25, 'X[11] <= -0.59\nsquared_error = 0.0\nsamples = 56\nvalue = -0.559'),
#  Text(0.162891046386192, 0.15, 'X[11] <= -0.616\nsquared_error = 0.0\nsamples = 27\nvalue = -0.572'),
#  Text(0.16181229773462782, 0.05, 'squared_error = 0.0\nsamples = 10\nvalue = -0.585'),
#  Text(0.16396979503775622, 0.05, 'squared_error = 0.0\nsamples = 17\nvalue = -0.565'),
#  Text(0.16720604099244876, 0.15, 'X[10] <= -0.247\nsquared_error = 0.0\nsamples = 29\nvalue = -0.546'),
#  Text(0.16612729234088458, 0.05, 'squared_error = 0.0\nsamples = 14\nvalue = -0.557'),
#  Text(0.16828478964401294, 0.05, 'squared_error = 0.0\nsamples = 15\nvalue = -0.537'),
#  Text(0.17367853290183388, 0.25, 'X[11] <= -0.616\nsquared_error = 0.0\nsamples = 30\nvalue = -0.519'),
#  Text(0.1715210355987055, 0.15, 'X[10] <= -0.105\nsquared_error = 0.0\nsamples = 5\nvalue = -0.549'),
#  Text(0.1704422869471413, 0.05, 'squared_error = 0.0\nsamples = 2\nvalue = -0.568'),
#  Text(0.1725997842502697, 0.05, 'squared_error = 0.0\nsamples = 3\nvalue = -0.537'),
#  Text(0.17583603020496225, 0.15, 'X[10] <= -0.085\nsquared_error = 0.0\nsamples = 25\nvalue = -0.513'),
#  Text(0.17475728155339806, 0.05, 'squared_error = 0.0\nsamples = 16\nvalue = -0.521'),
#  Text(0.17691477885652643, 0.05, 'squared_error = 0.0\nsamples = 9\nvalue = -0.499'),
#  Text(0.18959007551240561, 0.45, 'X[10] <= 0.24\nsquared_error = 0.005\nsamples = 27\nvalue = -0.451'),
#  Text(0.18284789644012944, 0.35, 'X[11] <= -0.649\nsquared_error = 0.002\nsamples = 18\nvalue = -0.491'),
#  Text(0.1790722761596548, 0.25, 'X[11] <= -0.712\nsquared_error = 0.0\nsamples = 7\nvalue = -0.537'),
#  Text(0.1779935275080906, 0.15, 'squared_error = 0.0\nsamples = 1\nvalue = -0.57'),
#  Text(0.18015102481121897, 0.15, 'X[7] <= -0.711\nsquared_error = 0.0\nsamples = 6\nvalue = -0.531'),
#  Text(0.1790722761596548, 0.05, 'squared_error = 0.0\nsamples = 2\nvalue = -0.543'),
#  Text(0.18122977346278318, 0.05, 'squared_error = 0.0\nsamples = 4\nvalue = -0.525'),
#  Text(0.1866235167206041, 0.25, 'X[7] <= 0.431\nsquared_error = 0.0\nsamples = 11\nvalue = -0.462'),
#  Text(0.18446601941747573, 0.15, 'X[8] <= 0.325\nsquared_error = 0.0\nsamples = 4\nvalue = -0.439'),
#  Text(0.18338727076591155, 0.05, 'squared_error = 0.0\nsamples = 3\nvalue = -0.449'),
#  Text(0.1855447680690399, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = -0.411'),
#  Text(0.18878101402373246, 0.15, 'X[2] <= -0.368\nsquared_error = 0.0\nsamples = 7\nvalue = -0.474'),
#  Text(0.18770226537216828, 0.05, 'squared_error = 0.0\nsamples = 4\nvalue = -0.479'),
#  Text(0.18985976267529667, 0.05, 'squared_error = 0.0\nsamples = 3\nvalue = -0.468'),
#  Text(0.19633225458468176, 0.35, 'X[6] <= 0.117\nsquared_error = 0.001\nsamples = 9\nvalue = -0.373'),
#  Text(0.19525350593311758, 0.25, 'X[2] <= -0.151\nsquared_error = 0.001\nsamples = 8\nvalue = -0.382'),
#  Text(0.1930960086299892, 0.15, 'X[7] <= 0.795\nsquared_error = 0.0\nsamples = 2\nvalue = -0.358'),
#  Text(0.19201725997842503, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = -0.355'),
#  Text(0.1941747572815534, 0.05, 'squared_error = -0.0\nsamples = 1\nvalue = -0.361'),
#  Text(0.19741100323624594, 0.15, 'X[11] <= -0.573\nsquared_error = 0.001\nsamples = 6\nvalue = -0.39'),
#  Text(0.19633225458468176, 0.05, 'squared_error = 0.0\nsamples = 5\nvalue = -0.398'),
#  Text(0.19848975188781015, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = -0.35'),
#  Text(0.19741100323624594, 0.25, 'squared_error = -0.0\nsamples = 1\nvalue = -0.295'),
#  Text(0.3376483279395901, 0.75, 'X[10] <= -0.125\nsquared_error = 0.025\nsamples = 2127\nvalue = -0.383'),
#  Text(0.2686084142394822, 0.65, 'X[11] <= -0.392\nsquared_error = 0.01\nsamples = 1496\nvalue = -0.455'),
#  Text(0.23408845738942827, 0.55, 'X[10] <= -0.45\nsquared_error = 0.003\nsamples = 754\nvalue = -0.532'),
#  Text(0.2168284789644013, 0.45, 'X[11] <= -0.491\nsquared_error = 0.002\nsamples = 443\nvalue = -0.564'),
#  Text(0.20819848975188782, 0.35, 'X[10] <= -0.612\nsquared_error = 0.001\nsamples = 201\nvalue = -0.6'),
#  Text(0.20388349514563106, 0.25, 'X[11] <= -0.524\nsquared_error = 0.0\nsamples = 91\nvalue = -0.621'),
#  Text(0.2017259978425027, 0.15, 'X[11] <= -0.537\nsquared_error = 0.0\nsamples = 52\nvalue = -0.634'),
#  Text(0.20064724919093851, 0.05, 'squared_error = 0.0\nsamples = 33\nvalue = -0.64'),
#  Text(0.20280474649406688, 0.05, 'squared_error = 0.0\nsamples = 19\nvalue = -0.624'),
#  Text(0.20604099244875945, 0.15, 'X[11] <= -0.497\nsquared_error = 0.0\nsamples = 39\nvalue = -0.604'),
#  Text(0.20496224379719524, 0.05, 'squared_error = 0.0\nsamples = 31\nvalue = -0.608'),
#  Text(0.20711974110032363, 0.05, 'squared_error = 0.0\nsamples = 8\nvalue = -0.59'),
#  Text(0.21251348435814454, 0.25, 'X[11] <= -0.53\nsquared_error = 0.0\nsamples = 110\nvalue = -0.582'),
#  Text(0.21035598705501618, 0.15, 'X[10] <= -0.551\nsquared_error = 0.0\nsamples = 40\nvalue = -0.601'),
#  Text(0.209277238403452, 0.05, 'squared_error = 0.0\nsamples = 21\nvalue = -0.612'),
#  Text(0.21143473570658036, 0.05, 'squared_error = 0.0\nsamples = 19\nvalue = -0.588'),
#  Text(0.21467098166127294, 0.15, 'X[10] <= -0.511\nsquared_error = 0.0\nsamples = 70\nvalue = -0.572'),
#  Text(0.21359223300970873, 0.05, 'squared_error = 0.0\nsamples = 45\nvalue = -0.579'),
#  Text(0.21574973031283712, 0.05, 'squared_error = 0.0\nsamples = 25\nvalue = -0.559'),
#  Text(0.22545846817691478, 0.35, 'X[11] <= -0.431\nsquared_error = 0.001\nsamples = 242\nvalue = -0.534'),
#  Text(0.22114347357065803, 0.25, 'X[10] <= -0.592\nsquared_error = 0.001\nsamples = 156\nvalue = -0.547'),
#  Text(0.21898597626752966, 0.15, 'X[11] <= -0.458\nsquared_error = 0.0\nsamples = 83\nvalue = -0.563'),
#  Text(0.21790722761596548, 0.05, 'squared_error = 0.0\nsamples = 44\nvalue = -0.574'),
#  Text(0.22006472491909385, 0.05, 'squared_error = 0.0\nsamples = 39\nvalue = -0.551'),
#  Text(0.22330097087378642, 0.15, 'X[11] <= -0.464\nsquared_error = 0.0\nsamples = 73\nvalue = -0.528'),
#  Text(0.2222222222222222, 0.05, 'squared_error = 0.0\nsamples = 37\nvalue = -0.539'),
#  Text(0.2243797195253506, 0.05, 'squared_error = 0.0\nsamples = 36\nvalue = -0.518'),
#  Text(0.2297734627831715, 0.25, 'X[10] <= -0.612\nsquared_error = 0.001\nsamples = 86\nvalue = -0.509'),
#  Text(0.22761596548004315, 0.15, 'X[11] <= -0.418\nsquared_error = 0.0\nsamples = 47\nvalue = -0.527'),
#  Text(0.22653721682847897, 0.05, 'squared_error = 0.0\nsamples = 18\nvalue = -0.537'),
#  Text(0.22869471413160733, 0.05, 'squared_error = 0.0\nsamples = 29\nvalue = -0.52'),
#  Text(0.2319309600862999, 0.15, 'X[10] <= -0.531\nsquared_error = 0.0\nsamples = 39\nvalue = -0.488'),
#  Text(0.2308522114347357, 0.05, 'squared_error = 0.0\nsamples = 20\nvalue = -0.498'),
#  Text(0.23300970873786409, 0.05, 'squared_error = 0.0\nsamples = 19\nvalue = -0.478'),
#  Text(0.2513484358144552, 0.45, 'X[11] <= -0.484\nsquared_error = 0.002\nsamples = 311\nvalue = -0.487'),
#  Text(0.24271844660194175, 0.35, 'X[10] <= -0.288\nsquared_error = 0.001\nsamples = 157\nvalue = -0.521'),
#  Text(0.238403451995685, 0.25, 'X[11] <= -0.524\nsquared_error = 0.0\nsamples = 106\nvalue = -0.537'),
#  Text(0.23624595469255663, 0.15, 'X[10] <= -0.348\nsquared_error = 0.0\nsamples = 59\nvalue = -0.55'),
#  Text(0.23516720604099245, 0.05, 'squared_error = 0.0\nsamples = 34\nvalue = -0.559'),
#  Text(0.2373247033441208, 0.05, 'squared_error = 0.0\nsamples = 25\nvalue = -0.539'),
#  Text(0.2405609492988134, 0.15, 'X[10] <= -0.389\nsquared_error = 0.0\nsamples = 47\nvalue = -0.521'),
#  Text(0.23948220064724918, 0.05, 'squared_error = 0.0\nsamples = 24\nvalue = -0.531'),
#  Text(0.24163969795037757, 0.05, 'squared_error = 0.0\nsamples = 23\nvalue = -0.51'),
#  Text(0.24703344120819848, 0.25, 'X[11] <= -0.504\nsquared_error = 0.001\nsamples = 51\nvalue = -0.486'),
#  Text(0.24487594390507011, 0.15, 'X[10] <= -0.247\nsquared_error = 0.0\nsamples = 31\nvalue = -0.5'),
#  Text(0.24379719525350593, 0.05, 'squared_error = 0.0\nsamples = 10\nvalue = -0.515'),
#  Text(0.2459546925566343, 0.05, 'squared_error = 0.0\nsamples = 21\nvalue = -0.493'),
#  Text(0.24919093851132687, 0.15, 'X[10] <= -0.217\nsquared_error = 0.0\nsamples = 20\nvalue = -0.464'),
#  Text(0.2481121898597627, 0.05, 'squared_error = 0.0\nsamples = 7\nvalue = -0.482'),
#  Text(0.25026968716289105, 0.05, 'squared_error = 0.0\nsamples = 13\nvalue = -0.455'),
#  Text(0.2599784250269687, 0.35, 'X[11] <= -0.431\nsquared_error = 0.001\nsamples = 154\nvalue = -0.452'),
#  Text(0.255663430420712, 0.25, 'X[10] <= -0.288\nsquared_error = 0.001\nsamples = 92\nvalue = -0.468'),
#  Text(0.2535059331175836, 0.15, 'X[10] <= -0.409\nsquared_error = 0.0\nsamples = 53\nvalue = -0.484'),
#  Text(0.2524271844660194, 0.05, 'squared_error = 0.0\nsamples = 16\nvalue = -0.503'),
#  Text(0.2545846817691478, 0.05, 'squared_error = 0.0\nsamples = 37\nvalue = -0.476'),
#  Text(0.25782092772384035, 0.15, 'X[11] <= -0.464\nsquared_error = 0.0\nsamples = 39\nvalue = -0.447'),
#  Text(0.25674217907227614, 0.05, 'squared_error = 0.0\nsamples = 20\nvalue = -0.458'),
#  Text(0.2588996763754045, 0.05, 'squared_error = 0.0\nsamples = 19\nvalue = -0.435'),
#  Text(0.26429341963322545, 0.25, 'X[10] <= -0.328\nsquared_error = 0.001\nsamples = 62\nvalue = -0.428'),
#  Text(0.2621359223300971, 0.15, 'X[11] <= -0.412\nsquared_error = 0.0\nsamples = 28\nvalue = -0.451'),
#  Text(0.26105717367853293, 0.05, 'squared_error = 0.0\nsamples = 14\nvalue = -0.459'),
#  Text(0.2632146709816613, 0.05, 'squared_error = 0.0\nsamples = 14\nvalue = -0.443'),
#  Text(0.2664509169363538, 0.15, 'X[10] <= -0.227\nsquared_error = 0.0\nsamples = 34\nvalue = -0.409'),
#  Text(0.26537216828478966, 0.05, 'squared_error = 0.0\nsamples = 18\nvalue = -0.422'),
#  Text(0.267529665587918, 0.05, 'squared_error = 0.0\nsamples = 16\nvalue = -0.394'),
#  Text(0.30312837108953616, 0.55, 'X[11] <= -0.286\nsquared_error = 0.004\nsamples = 742\nvalue = -0.377'),
#  Text(0.2858683926645092, 0.45, 'X[10] <= -0.45\nsquared_error = 0.002\nsamples = 436\nvalue = -0.412'),
#  Text(0.2772384034519957, 0.35, 'X[11] <= -0.345\nsquared_error = 0.001\nsamples = 253\nvalue = -0.443'),
#  Text(0.27292340884573896, 0.25, 'X[10] <= -0.632\nsquared_error = 0.0\nsamples = 112\nvalue = -0.471'),
#  Text(0.2707659115426106, 0.15, 'X[11] <= -0.365\nsquared_error = 0.0\nsamples = 41\nvalue = -0.492'),
#  Text(0.2696871628910464, 0.05, 'squared_error = 0.0\nsamples = 25\nvalue = -0.5'),
#  Text(0.27184466019417475, 0.05, 'squared_error = 0.0\nsamples = 16\nvalue = -0.479'),
#  Text(0.2750809061488673, 0.15, 'X[10] <= -0.551\nsquared_error = 0.0\nsamples = 71\nvalue = -0.458'),
#  Text(0.2740021574973031, 0.05, 'squared_error = 0.0\nsamples = 41\nvalue = -0.468'),
#  Text(0.2761596548004315, 0.05, 'squared_error = 0.0\nsamples = 30\nvalue = -0.445'),
#  Text(0.2815533980582524, 0.25, 'X[10] <= -0.571\nsquared_error = 0.001\nsamples = 141\nvalue = -0.421'),
#  Text(0.27939590075512405, 0.15, 'X[11] <= -0.319\nsquared_error = 0.0\nsamples = 75\nvalue = -0.436'),
#  Text(0.2783171521035599, 0.05, 'squared_error = 0.0\nsamples = 25\nvalue = -0.453'),
#  Text(0.28047464940668826, 0.05, 'squared_error = 0.0\nsamples = 50\nvalue = -0.428'),
#  Text(0.2837108953613808, 0.15, 'X[11] <= -0.306\nsquared_error = 0.0\nsamples = 66\nvalue = -0.404'),
#  Text(0.2826321467098166, 0.05, 'squared_error = 0.0\nsamples = 45\nvalue = -0.413'),
#  Text(0.284789644012945, 0.05, 'squared_error = 0.0\nsamples = 21\nvalue = -0.384'),
#  Text(0.29449838187702265, 0.35, 'X[10] <= -0.328\nsquared_error = 0.001\nsamples = 183\nvalue = -0.368'),
#  Text(0.2901833872707659, 0.25, 'X[11] <= -0.339\nsquared_error = 0.001\nsamples = 84\nvalue = -0.391'),
#  Text(0.28802588996763756, 0.15, 'X[11] <= -0.365\nsquared_error = 0.0\nsamples = 46\nvalue = -0.409'),
#  Text(0.28694714131607335, 0.05, 'squared_error = 0.0\nsamples = 21\nvalue = -0.422'),
#  Text(0.2891046386192017, 0.05, 'squared_error = 0.0\nsamples = 25\nvalue = -0.398'),
#  Text(0.2923408845738943, 0.15, 'X[11] <= -0.319\nsquared_error = 0.0\nsamples = 38\nvalue = -0.37'),
#  Text(0.2912621359223301, 0.05, 'squared_error = 0.0\nsamples = 17\nvalue = -0.381'),
#  Text(0.29341963322545844, 0.05, 'squared_error = 0.0\nsamples = 21\nvalue = -0.361'),
#  Text(0.2988133764832794, 0.25, 'X[11] <= -0.345\nsquared_error = 0.001\nsamples = 99\nvalue = -0.349'),
#  Text(0.296655879180151, 0.15, 'X[10] <= -0.227\nsquared_error = 0.0\nsamples = 46\nvalue = -0.369'),
#  Text(0.29557713052858686, 0.05, 'squared_error = 0.0\nsamples = 16\nvalue = -0.387'),
#  Text(0.2977346278317152, 0.05, 'squared_error = 0.0\nsamples = 30\nvalue = -0.359'),
#  Text(0.30097087378640774, 0.15, 'X[10] <= -0.227\nsquared_error = 0.0\nsamples = 53\nvalue = -0.331'),
#  Text(0.2998921251348436, 0.05, 'squared_error = 0.0\nsamples = 31\nvalue = -0.341'),
#  Text(0.30204962243797195, 0.05, 'squared_error = 0.0\nsamples = 22\nvalue = -0.317'),
#  Text(0.32038834951456313, 0.45, 'X[10] <= -0.43\nsquared_error = 0.002\nsamples = 306\nvalue = -0.328'),
#  Text(0.3117583603020496, 0.35, 'X[10] <= -0.571\nsquared_error = 0.001\nsamples = 186\nvalue = -0.358'),
#  Text(0.3074433656957929, 0.25, 'X[11] <= -0.233\nsquared_error = 0.001\nsamples = 93\nvalue = -0.378'),
#  Text(0.30528586839266453, 0.15, 'X[11] <= -0.273\nsquared_error = 0.0\nsamples = 54\nvalue = -0.394'),
#  Text(0.3042071197411003, 0.05, 'squared_error = 0.0\nsamples = 18\nvalue = -0.407'),
#  Text(0.3063646170442287, 0.05, 'squared_error = 0.0\nsamples = 36\nvalue = -0.387'),
#  Text(0.30960086299892126, 0.15, 'X[10] <= -0.632\nsquared_error = 0.0\nsamples = 39\nvalue = -0.356'),
#  Text(0.30852211434735705, 0.05, 'squared_error = 0.0\nsamples = 18\nvalue = -0.365'),
#  Text(0.3106796116504854, 0.05, 'squared_error = 0.0\nsamples = 21\nvalue = -0.348'),
#  Text(0.31607335490830635, 0.25, 'X[11] <= -0.24\nsquared_error = 0.001\nsamples = 93\nvalue = -0.337'),
#  Text(0.313915857605178, 0.15, 'X[10] <= -0.511\nsquared_error = 0.0\nsamples = 49\nvalue = -0.356'),
#  Text(0.31283710895361383, 0.05, 'squared_error = 0.0\nsamples = 25\nvalue = -0.366'),
#  Text(0.3149946062567422, 0.05, 'squared_error = 0.0\nsamples = 24\nvalue = -0.346'),
#  Text(0.3182308522114347, 0.15, 'X[11] <= -0.22\nsquared_error = 0.0\nsamples = 44\nvalue = -0.316'),
#  Text(0.31715210355987056, 0.05, 'squared_error = 0.0\nsamples = 20\nvalue = -0.329'),
#  Text(0.3193096008629989, 0.05, 'squared_error = 0.0\nsamples = 24\nvalue = -0.306'),
#  Text(0.3290183387270766, 0.35, 'X[10] <= -0.247\nsquared_error = 0.001\nsamples = 120\nvalue = -0.281'),
#  Text(0.32470334412081986, 0.25, 'X[11] <= -0.24\nsquared_error = 0.001\nsamples = 82\nvalue = -0.295'),
#  Text(0.3225458468176915, 0.15, 'X[10] <= -0.369\nsquared_error = 0.0\nsamples = 46\nvalue = -0.311'),
#  Text(0.3214670981661273, 0.05, 'squared_error = 0.0\nsamples = 12\nvalue = -0.334'),
#  Text(0.32362459546925565, 0.05, 'squared_error = 0.0\nsamples = 34\nvalue = -0.303'),
#  Text(0.3268608414239482, 0.15, 'X[10] <= -0.328\nsquared_error = 0.0\nsamples = 36\nvalue = -0.274'),
#  Text(0.325782092772384, 0.05, 'squared_error = 0.0\nsamples = 21\nvalue = -0.286'),
#  Text(0.32793959007551243, 0.05, 'squared_error = 0.0\nsamples = 15\nvalue = -0.258'),
#  Text(0.3333333333333333, 0.25, 'X[11] <= -0.246\nsquared_error = 0.001\nsamples = 38\nvalue = -0.25'),
#  Text(0.33117583603020495, 0.15, 'X[11] <= -0.266\nsquared_error = 0.0\nsamples = 18\nvalue = -0.274'),
#  Text(0.3300970873786408, 0.05, 'squared_error = 0.0\nsamples = 8\nvalue = -0.283'),
#  Text(0.33225458468176916, 0.05, 'squared_error = 0.0\nsamples = 10\nvalue = -0.266'),
#  Text(0.3354908306364617, 0.15, 'X[11] <= -0.22\nsquared_error = 0.0\nsamples = 20\nvalue = -0.229'),
#  Text(0.3344120819848975, 0.05, 'squared_error = 0.0\nsamples = 9\nvalue = -0.238'),
#  Text(0.3365695792880259, 0.05, 'squared_error = 0.0\nsamples = 11\nvalue = -0.222'),
#  Text(0.40668824163969797, 0.65, 'X[10] <= 0.24\nsquared_error = 0.02\nsamples = 631\nvalue = -0.212'),
#  Text(0.37216828478964403, 0.55, 'X[11] <= -0.365\nsquared_error = 0.008\nsamples = 396\nvalue = -0.28'),
#  Text(0.35490830636461707, 0.45, 'X[11] <= -0.438\nsquared_error = 0.003\nsamples = 159\nvalue = -0.367'),
#  Text(0.34627831715210355, 0.35, 'X[11] <= -0.484\nsquared_error = 0.002\nsamples = 85\nvalue = -0.402'),
#  Text(0.3419633225458468, 0.25, 'X[10] <= 0.118\nsquared_error = 0.001\nsamples = 38\nvalue = -0.43'),
#  Text(0.33980582524271846, 0.15, 'X[11] <= -0.544\nsquared_error = 0.001\nsamples = 31\nvalue = -0.44'),
#  Text(0.33872707659115425, 0.05, 'squared_error = 0.0\nsamples = 6\nvalue = -0.471'),
#  Text(0.3408845738942826, 0.05, 'squared_error = 0.0\nsamples = 25\nvalue = -0.432'),
#  Text(0.3441208198489752, 0.15, 'X[2] <= 0.066\nsquared_error = 0.0\nsamples = 7\nvalue = -0.388'),
#  Text(0.343042071197411, 0.05, 'squared_error = 0.0\nsamples = 5\nvalue = -0.396'),
#  Text(0.3451995685005394, 0.05, 'squared_error = -0.0\nsamples = 2\nvalue = -0.366'),
#  Text(0.3505933117583603, 0.25, 'X[10] <= 0.078\nsquared_error = 0.001\nsamples = 47\nvalue = -0.379'),
#  Text(0.3484358144552319, 0.15, 'X[10] <= -0.024\nsquared_error = 0.0\nsamples = 36\nvalue = -0.392'),
#  Text(0.34735706580366776, 0.05, 'squared_error = 0.0\nsamples = 18\nvalue = -0.406'),
#  Text(0.34951456310679613, 0.05, 'squared_error = 0.0\nsamples = 18\nvalue = -0.377'),
#  Text(0.35275080906148865, 0.15, 'X[10] <= 0.179\nsquared_error = 0.0\nsamples = 11\nvalue = -0.336'),
#  Text(0.3516720604099245, 0.05, 'squared_error = 0.0\nsamples = 4\nvalue = -0.349'),
#  Text(0.35382955771305286, 0.05, 'squared_error = 0.0\nsamples = 7\nvalue = -0.329'),
#  Text(0.3635382955771305, 0.35, 'X[10] <= 0.017\nsquared_error = 0.001\nsamples = 74\nvalue = -0.327'),
#  Text(0.3592233009708738, 0.25, 'X[11] <= -0.398\nsquared_error = 0.0\nsamples = 37\nvalue = -0.354'),
#  Text(0.35706580366774543, 0.15, 'X[10] <= -0.085\nsquared_error = 0.0\nsamples = 21\nvalue = -0.365'),
#  Text(0.3559870550161812, 0.05, 'squared_error = 0.0\nsamples = 9\nvalue = -0.377'),
#  Text(0.3581445523193096, 0.05, 'squared_error = 0.0\nsamples = 12\nvalue = -0.357'),
#  Text(0.36138079827400216, 0.15, 'X[10] <= -0.054\nsquared_error = 0.0\nsamples = 16\nvalue = -0.338'),
#  Text(0.36030204962243795, 0.05, 'squared_error = 0.0\nsamples = 11\nvalue = -0.342'),
#  Text(0.36245954692556637, 0.05, 'squared_error = 0.0\nsamples = 5\nvalue = -0.33'),
#  Text(0.36785329018338725, 0.25, 'X[11] <= -0.415\nsquared_error = 0.001\nsamples = 37\nvalue = -0.301'),
#  Text(0.3656957928802589, 0.15, 'X[10] <= 0.108\nsquared_error = 0.0\nsamples = 10\nvalue = -0.334'),
#  Text(0.36461704422869473, 0.05, 'squared_error = 0.0\nsamples = 6\nvalue = -0.344'),
#  Text(0.3667745415318231, 0.05, 'squared_error = 0.0\nsamples = 4\nvalue = -0.32'),
#  Text(0.37001078748651567, 0.15, 'X[10] <= 0.159\nsquared_error = 0.0\nsamples = 27\nvalue = -0.288'),
#  Text(0.36893203883495146, 0.05, 'squared_error = 0.0\nsamples = 16\nvalue = -0.301'),
#  Text(0.3710895361380798, 0.05, 'squared_error = 0.0\nsamples = 11\nvalue = -0.27'),
#  Text(0.389428263214671, 0.45, 'X[11] <= -0.273\nsquared_error = 0.002\nsamples = 237\nvalue = -0.221'),
#  Text(0.3807982740021575, 0.35, 'X[10] <= 0.017\nsquared_error = 0.001\nsamples = 125\nvalue = -0.254'),
#  Text(0.37648327939590076, 0.25, 'X[11] <= -0.319\nsquared_error = 0.001\nsamples = 56\nvalue = -0.282'),
#  Text(0.3743257820927724, 0.15, 'X[10] <= -0.085\nsquared_error = 0.0\nsamples = 28\nvalue = -0.302'),
#  Text(0.3732470334412082, 0.05, 'squared_error = 0.0\nsamples = 11\nvalue = -0.314'),
#  Text(0.37540453074433655, 0.05, 'squared_error = 0.0\nsamples = 17\nvalue = -0.294'),
#  Text(0.3786407766990291, 0.15, 'X[11] <= -0.293\nsquared_error = 0.0\nsamples = 28\nvalue = -0.261'),
#  Text(0.3775620280474649, 0.05, 'squared_error = 0.0\nsamples = 10\nvalue = -0.277'),
#  Text(0.37971952535059333, 0.05, 'squared_error = 0.0\nsamples = 18\nvalue = -0.252'),
#  Text(0.3851132686084142, 0.25, 'X[11] <= -0.312\nsquared_error = 0.001\nsamples = 69\nvalue = -0.231'),
#  Text(0.38295577130528585, 0.15, 'X[10] <= 0.138\nsquared_error = 0.0\nsamples = 33\nvalue = -0.252'),
#  Text(0.3818770226537217, 0.05, 'squared_error = 0.0\nsamples = 20\nvalue = -0.265'),
#  Text(0.38403451995685006, 0.05, 'squared_error = 0.0\nsamples = 13\nvalue = -0.232'),
#  Text(0.38727076591154264, 0.15, 'X[10] <= 0.118\nsquared_error = 0.0\nsamples = 36\nvalue = -0.212'),
#  Text(0.3861920172599784, 0.05, 'squared_error = 0.0\nsamples = 19\nvalue = -0.227'),
#  Text(0.3883495145631068, 0.05, 'squared_error = 0.0\nsamples = 17\nvalue = -0.196'),
#  Text(0.39805825242718446, 0.35, 'X[10] <= 0.057\nsquared_error = 0.001\nsamples = 112\nvalue = -0.184'),
#  Text(0.39374325782092773, 0.25, 'X[11] <= -0.227\nsquared_error = 0.0\nsamples = 61\nvalue = -0.208'),
#  Text(0.39158576051779936, 0.15, 'X[10] <= -0.064\nsquared_error = 0.0\nsamples = 41\nvalue = -0.218'),
#  Text(0.39050701186623515, 0.05, 'squared_error = 0.0\nsamples = 13\nvalue = -0.233'),
#  Text(0.3926645091693635, 0.05, 'squared_error = 0.0\nsamples = 28\nvalue = -0.211'),
#  Text(0.3959007551240561, 0.15, 'X[10] <= -0.044\nsquared_error = 0.0\nsamples = 20\nvalue = -0.188'),
#  Text(0.3948220064724919, 0.05, 'squared_error = 0.0\nsamples = 10\nvalue = -0.202'),
#  Text(0.3969795037756203, 0.05, 'squared_error = 0.0\nsamples = 10\nvalue = -0.174'),
#  Text(0.4023732470334412, 0.25, 'X[11] <= -0.246\nsquared_error = 0.001\nsamples = 51\nvalue = -0.156'),
#  Text(0.4002157497303128, 0.15, 'X[10] <= 0.138\nsquared_error = 0.0\nsamples = 18\nvalue = -0.181'),
#  Text(0.39913700107874867, 0.05, 'squared_error = 0.0\nsamples = 11\nvalue = -0.191'),
#  Text(0.40129449838187703, 0.05, 'squared_error = 0.0\nsamples = 7\nvalue = -0.166'),
#  Text(0.4045307443365696, 0.15, 'X[10] <= 0.159\nsquared_error = 0.0\nsamples = 33\nvalue = -0.142'),
#  Text(0.4034519956850054, 0.05, 'squared_error = 0.0\nsamples = 17\nvalue = -0.153'),
#  Text(0.40560949298813376, 0.05, 'squared_error = 0.0\nsamples = 16\nvalue = -0.13'),
#  Text(0.4412081984897519, 0.55, 'X[11] <= -0.385\nsquared_error = 0.021\nsamples = 235\nvalue = -0.098'),
#  Text(0.42394822006472493, 0.45, 'X[11] <= -0.491\nsquared_error = 0.007\nsamples = 68\nvalue = -0.219'),
#  Text(0.4153182308522114, 0.35, 'X[7] <= 0.795\nsquared_error = 0.003\nsamples = 11\nvalue = -0.285'),
#  Text(0.4110032362459547, 0.25, 'X[7] <= 0.691\nsquared_error = 0.001\nsamples = 6\nvalue = -0.241'),
#  Text(0.40884573894282633, 0.15, 'X[2] <= 0.066\nsquared_error = 0.0\nsamples = 3\nvalue = -0.219'),
#  Text(0.4077669902912621, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = -0.207'),
#  Text(0.4099244875943905, 0.05, 'squared_error = 0.0\nsamples = 2\nvalue = -0.226'),
#  Text(0.41316073354908306, 0.15, 'X[2] <= 0.572\nsquared_error = 0.0\nsamples = 3\nvalue = -0.262'),
#  Text(0.4120819848975189, 0.05, 'squared_error = 0.0\nsamples = 2\nvalue = -0.275'),
#  Text(0.41423948220064727, 0.05, 'squared_error = -0.0\nsamples = 1\nvalue = -0.234'),
#  Text(0.41963322545846815, 0.25, 'X[11] <= -0.524\nsquared_error = 0.001\nsamples = 5\nvalue = -0.339'),
#  Text(0.4174757281553398, 0.15, 'X[6] <= 0.117\nsquared_error = 0.0\nsamples = 2\nvalue = -0.372'),
#  Text(0.41639697950377563, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = -0.377'),
#  Text(0.418554476806904, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = -0.366'),
#  Text(0.42179072276159657, 0.15, 'X[5] <= -0.393\nsquared_error = 0.0\nsamples = 3\nvalue = -0.317'),
#  Text(0.42071197411003236, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = -0.289'),
#  Text(0.4228694714131607, 0.05, 'squared_error = 0.0\nsamples = 2\nvalue = -0.331'),
#  Text(0.4325782092772384, 0.35, 'X[1] <= -0.005\nsquared_error = 0.006\nsamples = 57\nvalue = -0.206'),
#  Text(0.42826321467098166, 0.25, 'X[2] <= -0.151\nsquared_error = 0.003\nsamples = 50\nvalue = -0.22'),
#  Text(0.4261057173678533, 0.15, 'X[11] <= -0.431\nsquared_error = 0.001\nsamples = 16\nvalue = -0.252'),
#  Text(0.4250269687162891, 0.05, 'squared_error = 0.0\nsamples = 8\nvalue = -0.265'),
#  Text(0.42718446601941745, 0.05, 'squared_error = 0.0\nsamples = 8\nvalue = -0.238'),
#  Text(0.43042071197411, 0.15, 'X[5] <= -0.393\nsquared_error = 0.004\nsamples = 34\nvalue = -0.204'),
#  Text(0.42934196332254587, 0.05, 'squared_error = 0.004\nsamples = 25\nvalue = -0.193'),
#  Text(0.43149946062567424, 0.05, 'squared_error = 0.0\nsamples = 9\nvalue = -0.237'),
#  Text(0.4368932038834951, 0.25, 'X[8] <= -0.556\nsquared_error = 0.017\nsamples = 7\nvalue = -0.109'),
#  Text(0.43473570658036675, 0.15, 'X[11] <= -0.435\nsquared_error = 0.011\nsamples = 2\nvalue = 0.064'),
#  Text(0.4336569579288026, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = -0.041'),
#  Text(0.43581445523193096, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = 0.168'),
#  Text(0.43905070118662354, 0.15, 'X[0] <= -0.001\nsquared_error = 0.002\nsamples = 5\nvalue = -0.178'),
#  Text(0.43797195253505933, 0.05, 'squared_error = 0.001\nsamples = 4\nvalue = -0.197'),
#  Text(0.4401294498381877, 0.05, 'squared_error = -0.0\nsamples = 1\nvalue = -0.102'),
#  Text(0.45846817691477887, 0.45, 'X[7] <= -0.036\nsquared_error = 0.018\nsamples = 167\nvalue = -0.049'),
#  Text(0.44983818770226536, 0.35, 'X[7] <= -0.244\nsquared_error = 0.026\nsamples = 55\nvalue = 0.019'),
#  Text(0.44552319309600863, 0.25, 'X[11] <= -0.253\nsquared_error = 0.018\nsamples = 39\nvalue = -0.014'),
#  Text(0.44336569579288027, 0.15, 'X[8] <= -0.737\nsquared_error = 0.02\nsamples = 26\nvalue = -0.046'),
#  Text(0.44228694714131606, 0.05, 'squared_error = 0.024\nsamples = 16\nvalue = -0.007'),
#  Text(0.4444444444444444, 0.05, 'squared_error = 0.006\nsamples = 10\nvalue = -0.107'),
#  Text(0.447680690399137, 0.15, 'X[1] <= -0.005\nsquared_error = 0.008\nsamples = 13\nvalue = 0.05'),
#  Text(0.44660194174757284, 0.05, 'squared_error = 0.005\nsamples = 9\nvalue = 0.086'),
#  Text(0.4487594390507012, 0.05, 'squared_error = 0.005\nsamples = 4\nvalue = -0.033'),
#  Text(0.45415318230852214, 0.25, 'X[2] <= 0.644\nsquared_error = 0.038\nsamples = 16\nvalue = 0.1'),
#  Text(0.4519956850053937, 0.15, 'X[2] <= 0.282\nsquared_error = 0.039\nsamples = 11\nvalue = 0.162'),
#  Text(0.45091693635382957, 0.05, 'squared_error = 0.008\nsamples = 5\nvalue = 0.019'),
#  Text(0.45307443365695793, 0.05, 'squared_error = 0.033\nsamples = 6\nvalue = 0.281'),
#  Text(0.4563106796116505, 0.15, 'X[11] <= -0.289\nsquared_error = 0.008\nsamples = 5\nvalue = -0.036'),
#  Text(0.4552319309600863, 0.05, 'squared_error = 0.002\nsamples = 3\nvalue = -0.093'),
#  Text(0.45738942826321466, 0.05, 'squared_error = 0.006\nsamples = 2\nvalue = 0.05'),
#  Text(0.4670981661272923, 0.35, 'X[11] <= -0.266\nsquared_error = 0.011\nsamples = 112\nvalue = -0.082'),
#  Text(0.4627831715210356, 0.25, 'X[2] <= -0.296\nsquared_error = 0.006\nsamples = 56\nvalue = -0.128'),
#  Text(0.46062567421790723, 0.15, 'X[11] <= -0.372\nsquared_error = 0.016\nsamples = 9\nvalue = -0.052'),
#  Text(0.459546925566343, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = 0.268'),
#  Text(0.4617044228694714, 0.05, 'squared_error = 0.003\nsamples = 8\nvalue = -0.092'),
#  Text(0.46494066882416396, 0.15, 'X[11] <= -0.326\nsquared_error = 0.002\nsamples = 47\nvalue = -0.143'),
#  Text(0.4638619201725998, 0.05, 'squared_error = 0.002\nsamples = 19\nvalue = -0.169'),
#  Text(0.46601941747572817, 0.05, 'squared_error = 0.002\nsamples = 28\nvalue = -0.125'),
#  Text(0.4714131607335491, 0.25, 'X[5] <= -0.393\nsquared_error = 0.012\nsamples = 56\nvalue = -0.035'),
#  Text(0.4692556634304207, 0.15, 'X[7] <= 0.795\nsquared_error = 0.019\nsamples = 28\nvalue = -0.003'),
#  Text(0.46817691477885653, 0.05, 'squared_error = 0.002\nsamples = 13\nvalue = -0.074'),
#  Text(0.4703344120819849, 0.05, 'squared_error = 0.026\nsamples = 15\nvalue = 0.058'),
#  Text(0.47357065803667747, 0.15, 'X[11] <= -0.227\nsquared_error = 0.002\nsamples = 28\nvalue = -0.068'),
#  Text(0.47249190938511326, 0.05, 'squared_error = 0.002\nsamples = 23\nvalue = -0.08'),
#  Text(0.4746494066882416, 0.05, 'squared_error = 0.0\nsamples = 5\nvalue = -0.008'),
#  Text(0.7431903991370011, 0.85, 'X[11] <= 0.163\nsquared_error = 0.061\nsamples = 6206\nvalue = 0.316'),
#  Text(0.6106391585760518, 0.75, 'X[10] <= 0.199\nsquared_error = 0.037\nsamples = 1842\nvalue = 0.006'),
#  Text(0.5447680690399137, 0.65, 'X[11] <= -0.028\nsquared_error = 0.012\nsamples = 1184\nvalue = -0.1'),
#  Text(0.5102481121898598, 0.55, 'X[10] <= -0.288\nsquared_error = 0.006\nsamples = 621\nvalue = -0.17'),
#  Text(0.4929881337648328, 0.45, 'X[11] <= -0.114\nsquared_error = 0.003\nsamples = 309\nvalue = -0.232'),
#  Text(0.4843581445523193, 0.35, 'X[10] <= -0.43\nsquared_error = 0.001\nsamples = 159\nvalue = -0.266'),
#  Text(0.48004314994606256, 0.25, 'X[10] <= -0.551\nsquared_error = 0.001\nsamples = 109\nvalue = -0.285'),
#  Text(0.4778856526429342, 0.15, 'X[11] <= -0.167\nsquared_error = 0.0\nsamples = 63\nvalue = -0.297'),
#  Text(0.47680690399137, 0.05, 'squared_error = 0.0\nsamples = 24\nvalue = -0.314'),
#  Text(0.47896440129449835, 0.05, 'squared_error = 0.0\nsamples = 39\nvalue = -0.287'),
#  Text(0.48220064724919093, 0.15, 'X[11] <= -0.141\nsquared_error = 0.0\nsamples = 46\nvalue = -0.268'),
#  Text(0.4811218985976268, 0.05, 'squared_error = 0.0\nsamples = 34\nvalue = -0.277'),
#  Text(0.48327939590075514, 0.05, 'squared_error = 0.0\nsamples = 12\nvalue = -0.242'),
#  Text(0.4886731391585761, 0.25, 'X[11] <= -0.16\nsquared_error = 0.0\nsamples = 50\nvalue = -0.224'),
#  Text(0.48651564185544766, 0.15, 'X[10] <= -0.389\nsquared_error = 0.0\nsamples = 20\nvalue = -0.242'),
#  Text(0.4854368932038835, 0.05, 'squared_error = 0.0\nsamples = 5\nvalue = -0.259'),
#  Text(0.48759439050701187, 0.05, 'squared_error = 0.0\nsamples = 15\nvalue = -0.236'),
#  Text(0.49083063646170444, 0.15, 'X[10] <= -0.389\nsquared_error = 0.0\nsamples = 30\nvalue = -0.212'),
#  Text(0.48975188781014023, 0.05, 'squared_error = 0.0\nsamples = 9\nvalue = -0.224'),
#  Text(0.4919093851132686, 0.05, 'squared_error = 0.0\nsamples = 21\nvalue = -0.207'),
#  Text(0.5016181229773463, 0.35, 'X[10] <= -0.43\nsquared_error = 0.001\nsamples = 150\nvalue = -0.196'),
#  Text(0.49730312837108953, 0.25, 'X[10] <= -0.571\nsquared_error = 0.001\nsamples = 110\nvalue = -0.212'),
#  Text(0.49514563106796117, 0.15, 'X[11] <= -0.075\nsquared_error = 0.0\nsamples = 46\nvalue = -0.233'),
#  Text(0.49406688241639696, 0.05, 'squared_error = 0.0\nsamples = 22\nvalue = -0.252'),
#  Text(0.4962243797195254, 0.05, 'squared_error = 0.0\nsamples = 24\nvalue = -0.215'),
#  Text(0.4994606256742179, 0.15, 'X[11] <= -0.075\nsquared_error = 0.0\nsamples = 64\nvalue = -0.196'),
#  Text(0.49838187702265374, 0.05, 'squared_error = 0.0\nsamples = 29\nvalue = -0.212'),
#  Text(0.5005393743257821, 0.05, 'squared_error = 0.0\nsamples = 35\nvalue = -0.183'),
#  Text(0.505933117583603, 0.25, 'X[11] <= -0.094\nsquared_error = 0.001\nsamples = 40\nvalue = -0.154'),
#  Text(0.5037756202804746, 0.15, 'X[10] <= -0.338\nsquared_error = 0.0\nsamples = 7\nvalue = -0.192'),
#  Text(0.5026968716289104, 0.05, 'squared_error = 0.0\nsamples = 6\nvalue = -0.195'),
#  Text(0.5048543689320388, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = -0.179'),
#  Text(0.5080906148867314, 0.15, 'X[11] <= -0.048\nsquared_error = 0.0\nsamples = 33\nvalue = -0.146'),
#  Text(0.5070118662351673, 0.05, 'squared_error = 0.0\nsamples = 21\nvalue = -0.155'),
#  Text(0.5091693635382956, 0.05, 'squared_error = 0.0\nsamples = 12\nvalue = -0.129'),
#  Text(0.5275080906148867, 0.45, 'X[10] <= -0.024\nsquared_error = 0.003\nsamples = 312\nvalue = -0.109'),
#  Text(0.5188781014023732, 0.35, 'X[11] <= -0.114\nsquared_error = 0.002\nsamples = 187\nvalue = -0.136'),
#  Text(0.5145631067961165, 0.25, 'X[10] <= -0.146\nsquared_error = 0.001\nsamples = 88\nvalue = -0.171'),
#  Text(0.5124056094929881, 0.15, 'X[11] <= -0.147\nsquared_error = 0.0\nsamples = 49\nvalue = -0.189'),
#  Text(0.511326860841424, 0.05, 'squared_error = 0.0\nsamples = 28\nvalue = -0.202'),
#  Text(0.5134843581445523, 0.05, 'squared_error = 0.0\nsamples = 21\nvalue = -0.171'),
#  Text(0.5167206040992449, 0.15, 'X[11] <= -0.154\nsquared_error = 0.0\nsamples = 39\nvalue = -0.149'),
#  Text(0.5156418554476807, 0.05, 'squared_error = 0.0\nsamples = 19\nvalue = -0.165'),
# ...
#  Text(0.819848975188781, 0.05, 'squared_error = -0.0\nsamples = 1\nvalue = 0.4'),
#  Text(0.8252427184466019, 0.25, 'X[2] <= 0.861\nsquared_error = 0.005\nsamples = 71\nvalue = 0.456'),
#  Text(0.8230852211434736, 0.15, 'X[2] <= -0.296\nsquared_error = 0.002\nsamples = 46\nvalue = 0.481'),
#  Text(0.8220064724919094, 0.05, 'squared_error = 0.002\nsamples = 4\nvalue = 0.414'),
#  Text(0.8241639697950378, 0.05, 'squared_error = 0.002\nsamples = 42\nvalue = 0.487'),
#  Text(0.8274002157497303, 0.15, 'X[7] <= 0.795\nsquared_error = 0.008\nsamples = 25\nvalue = 0.41'),
#  Text(0.8263214670981661, 0.05, 'squared_error = 0.008\nsamples = 12\nvalue = 0.362'),
#  Text(0.8284789644012945, 0.05, 'squared_error = 0.004\nsamples = 13\nvalue = 0.455'),
#  Text(0.8381877022653722, 0.35, 'X[8] <= -0.167\nsquared_error = 0.007\nsamples = 100\nvalue = 0.355'),
#  Text(0.8338727076591155, 0.25, 'X[1] <= -0.005\nsquared_error = 0.007\nsamples = 83\nvalue = 0.366'),
#  Text(0.8317152103559871, 0.15, 'X[9] <= -0.578\nsquared_error = 0.003\nsamples = 16\nvalue = 0.32'),
#  Text(0.8306364617044228, 0.05, 'squared_error = 0.0\nsamples = 3\nvalue = 0.389'),
#  Text(0.8327939590075513, 0.05, 'squared_error = 0.003\nsamples = 13\nvalue = 0.304'),
#  Text(0.8360302049622438, 0.15, 'X[11] <= 0.223\nsquared_error = 0.007\nsamples = 67\nvalue = 0.377'),
#  Text(0.8349514563106796, 0.05, 'squared_error = 0.007\nsamples = 47\nvalue = 0.364'),
#  Text(0.837108953613808, 0.05, 'squared_error = 0.006\nsamples = 20\nvalue = 0.41'),
#  Text(0.8425026968716289, 0.25, 'X[11] <= 0.216\nsquared_error = 0.005\nsamples = 17\nvalue = 0.3'),
#  Text(0.8403451995685005, 0.15, 'X[9] <= -0.578\nsquared_error = 0.002\nsamples = 11\nvalue = 0.27'),
#  Text(0.8392664509169363, 0.05, 'squared_error = 0.003\nsamples = 2\nvalue = 0.323'),
#  Text(0.8414239482200647, 0.05, 'squared_error = 0.001\nsamples = 9\nvalue = 0.258'),
#  Text(0.8446601941747572, 0.15, 'X[4] <= 0.497\nsquared_error = 0.006\nsamples = 6\nvalue = 0.355'),
#  Text(0.8435814455231931, 0.05, 'squared_error = 0.002\nsamples = 5\nvalue = 0.325'),
#  Text(0.8457389428263214, 0.05, 'squared_error = -0.0\nsamples = 1\nvalue = 0.505'),
#  Text(0.8605717367853291, 0.45, 'X[5] <= -0.393\nsquared_error = 0.004\nsamples = 263\nvalue = 0.46'),
#  Text(0.8527508090614887, 0.35, 'X[7] <= -0.608\nsquared_error = 0.002\nsamples = 131\nvalue = 0.484'),
#  Text(0.8500539374325782, 0.25, 'X[11] <= 0.355\nsquared_error = 0.003\nsamples = 7\nvalue = 0.378'),
#  Text(0.8489751887810141, 0.15, 'X[2] <= -0.224\nsquared_error = 0.0\nsamples = 6\nvalue = 0.357'),
#  Text(0.8478964401294499, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = 0.323'),
#  Text(0.8500539374325782, 0.05, 'squared_error = 0.0\nsamples = 5\nvalue = 0.364'),
#  Text(0.8511326860841424, 0.15, 'squared_error = -0.0\nsamples = 1\nvalue = 0.505'),
#  Text(0.8554476806903991, 0.25, 'X[1] <= -0.005\nsquared_error = 0.001\nsamples = 124\nvalue = 0.49'),
#  Text(0.8532901833872708, 0.15, 'X[2] <= 0.572\nsquared_error = 0.0\nsamples = 80\nvalue = 0.502'),
#  Text(0.8522114347357066, 0.05, 'squared_error = 0.0\nsamples = 52\nvalue = 0.504'),
#  Text(0.8543689320388349, 0.05, 'squared_error = 0.0\nsamples = 28\nvalue = 0.497'),
#  Text(0.8576051779935275, 0.15, 'X[7] <= 0.275\nsquared_error = 0.003\nsamples = 44\nvalue = 0.468'),
#  Text(0.8565264293419633, 0.05, 'squared_error = 0.004\nsamples = 10\nvalue = 0.409'),
#  Text(0.8586839266450917, 0.05, 'squared_error = 0.001\nsamples = 34\nvalue = 0.486'),
#  Text(0.8683926645091694, 0.35, 'X[11] <= 0.302\nsquared_error = 0.004\nsamples = 132\nvalue = 0.435'),
#  Text(0.8640776699029126, 0.25, 'X[1] <= -0.005\nsquared_error = 0.004\nsamples = 55\nvalue = 0.402'),
#  Text(0.8619201725997843, 0.15, 'X[6] <= 0.117\nsquared_error = 0.002\nsamples = 9\nvalue = 0.339'),
#  Text(0.86084142394822, 0.05, 'squared_error = 0.001\nsamples = 7\nvalue = 0.325'),
#  Text(0.8629989212513485, 0.05, 'squared_error = 0.001\nsamples = 2\nvalue = 0.389'),
#  Text(0.866235167206041, 0.15, 'X[8] <= -0.685\nsquared_error = 0.004\nsamples = 46\nvalue = 0.414'),
#  Text(0.8651564185544768, 0.05, 'squared_error = 0.003\nsamples = 26\nvalue = 0.435'),
#  Text(0.8673139158576052, 0.05, 'squared_error = 0.004\nsamples = 20\nvalue = 0.387'),
#  Text(0.8727076591154261, 0.25, 'X[2] <= 0.572\nsquared_error = 0.003\nsamples = 77\nvalue = 0.459'),
#  Text(0.8705501618122977, 0.15, 'X[8] <= -0.53\nsquared_error = 0.002\nsamples = 64\nvalue = 0.468'),
#  Text(0.8694714131607335, 0.05, 'squared_error = 0.001\nsamples = 38\nvalue = 0.48'),
#  Text(0.8716289104638619, 0.05, 'squared_error = 0.003\nsamples = 26\nvalue = 0.45'),
#  Text(0.8748651564185544, 0.15, 'X[11] <= 0.368\nsquared_error = 0.003\nsamples = 13\nvalue = 0.417'),
#  Text(0.8737864077669902, 0.05, 'squared_error = 0.002\nsamples = 10\nvalue = 0.392'),
#  Text(0.8759439050701187, 0.05, 'squared_error = 0.0\nsamples = 3\nvalue = 0.501'),
#  Text(0.940062028047465, 0.65, 'X[10] <= -0.348\nsquared_error = 0.003\nsamples = 3445\nvalue = 0.489'),
#  Text(0.9092502696871629, 0.55, 'X[11] <= 0.434\nsquared_error = 0.011\nsamples = 535\nvalue = 0.44'),
#  Text(0.8940129449838188, 0.45, 'X[10] <= -0.511\nsquared_error = 0.001\nsamples = 30\nvalue = 0.207'),
#  Text(0.8856526429341963, 0.35, 'X[10] <= -0.622\nsquared_error = 0.0\nsamples = 17\nvalue = 0.188'),
#  Text(0.8813376483279396, 0.25, 'X[1] <= -0.005\nsquared_error = 0.0\nsamples = 5\nvalue = 0.171'),
#  Text(0.8791801510248112, 0.15, 'X[11] <= 0.404\nsquared_error = 0.0\nsamples = 3\nvalue = 0.163'),
#  Text(0.8781014023732471, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = 0.152'),
#  Text(0.8802588996763754, 0.05, 'squared_error = 0.0\nsamples = 2\nvalue = 0.168'),
#  Text(0.883495145631068, 0.15, 'X[8] <= 0.014\nsquared_error = 0.0\nsamples = 2\nvalue = 0.182'),
#  Text(0.8824163969795038, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = 0.185'),
#  Text(0.8845738942826321, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = 0.179'),
#  Text(0.889967637540453, 0.25, 'X[11] <= 0.408\nsquared_error = 0.0\nsamples = 12\nvalue = 0.195'),
#  Text(0.8878101402373247, 0.15, 'X[11] <= 0.395\nsquared_error = 0.0\nsamples = 5\nvalue = 0.189'),
#  Text(0.8867313915857605, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = 0.185'),
#  Text(0.8888888888888888, 0.05, 'squared_error = 0.0\nsamples = 4\nvalue = 0.19'),
#  Text(0.8921251348435815, 0.15, 'X[10] <= -0.541\nsquared_error = 0.0\nsamples = 7\nvalue = 0.2'),
#  Text(0.8910463861920173, 0.05, 'squared_error = 0.0\nsamples = 4\nvalue = 0.193'),
#  Text(0.8932038834951457, 0.05, 'squared_error = 0.0\nsamples = 3\nvalue = 0.209'),
#  Text(0.9023732470334412, 0.35, 'X[10] <= -0.409\nsquared_error = 0.0\nsamples = 13\nvalue = 0.231'),
#  Text(0.8985976267529665, 0.25, 'X[11] <= 0.421\nsquared_error = 0.0\nsamples = 7\nvalue = 0.216'),
#  Text(0.8964401294498382, 0.15, 'X[6] <= 0.117\nsquared_error = 0.0\nsamples = 5\nvalue = 0.211'),
#  Text(0.895361380798274, 0.05, 'squared_error = 0.0\nsamples = 3\nvalue = 0.214'),
#  Text(0.8975188781014024, 0.05, 'squared_error = 0.0\nsamples = 2\nvalue = 0.207'),
#  Text(0.9007551240560949, 0.15, 'X[6] <= 0.117\nsquared_error = 0.0\nsamples = 2\nvalue = 0.229'),
#  Text(0.8996763754045307, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = 0.223'),
#  Text(0.9018338727076591, 0.05, 'squared_error = -0.0\nsamples = 1\nvalue = 0.235'),
#  Text(0.9061488673139159, 0.25, 'X[0] <= -0.001\nsquared_error = 0.0\nsamples = 6\nvalue = 0.247'),
#  Text(0.9050701186623517, 0.15, 'X[8] <= -0.193\nsquared_error = 0.0\nsamples = 5\nvalue = 0.244'),
#  Text(0.9039913700107874, 0.05, 'squared_error = 0.0\nsamples = 2\nvalue = 0.24'),
#  Text(0.9061488673139159, 0.05, 'squared_error = 0.0\nsamples = 3\nvalue = 0.247'),
#  Text(0.9072276159654801, 0.15, 'squared_error = 0.0\nsamples = 1\nvalue = 0.262'),
#  Text(0.924487594390507, 0.45, 'X[10] <= -0.571\nsquared_error = 0.008\nsamples = 505\nvalue = 0.453'),
#  Text(0.9158576051779935, 0.35, 'X[2] <= -0.441\nsquared_error = 0.013\nsamples = 103\nvalue = 0.411'),
#  Text(0.9115426105717368, 0.25, 'X[1] <= -0.005\nsquared_error = 0.013\nsamples = 70\nvalue = 0.425'),
#  Text(0.9093851132686084, 0.15, 'X[10] <= -0.612\nsquared_error = 0.014\nsamples = 24\nvalue = 0.363'),
#  Text(0.9083063646170443, 0.05, 'squared_error = 0.002\nsamples = 7\nvalue = 0.253'),
#  Text(0.9104638619201726, 0.05, 'squared_error = 0.012\nsamples = 17\nvalue = 0.408'),
#  Text(0.9137001078748651, 0.15, 'X[7] <= -0.296\nsquared_error = 0.008\nsamples = 46\nvalue = 0.457'),
#  Text(0.912621359223301, 0.05, 'squared_error = 0.006\nsamples = 42\nvalue = 0.469'),
#  Text(0.9147788565264293, 0.05, 'squared_error = 0.016\nsamples = 4\nvalue = 0.328'),
#  Text(0.9201725997842503, 0.25, 'X[4] <= -0.75\nsquared_error = 0.012\nsamples = 33\nvalue = 0.381'),
#  Text(0.918015102481122, 0.15, 'X[8] <= 0.662\nsquared_error = 0.003\nsamples = 7\nvalue = 0.46'),
#  Text(0.9169363538295577, 0.05, 'squared_error = 0.003\nsamples = 5\nvalue = 0.442'),
#  Text(0.919093851132686, 0.05, 'squared_error = -0.0\nsamples = 2\nvalue = 0.505'),
#  Text(0.9223300970873787, 0.15, 'X[8] <= -0.219\nsquared_error = 0.012\nsamples = 26\nvalue = 0.359'),
#  Text(0.9212513484358145, 0.05, 'squared_error = 0.009\nsamples = 13\nvalue = 0.407'),
#  Text(0.9234088457389428, 0.05, 'squared_error = 0.01\nsamples = 13\nvalue = 0.312'),
#  Text(0.9331175836030206, 0.35, 'X[1] <= -0.005\nsquared_error = 0.006\nsamples = 402\nvalue = 0.464'),
#  Text(0.9288025889967637, 0.25, 'X[0] <= -0.001\nsquared_error = 0.008\nsamples = 139\nvalue = 0.442'),
#  Text(0.9266450916936354, 0.15, 'X[10] <= -0.531\nsquared_error = 0.008\nsamples = 30\nvalue = 0.385'),
#  Text(0.9255663430420712, 0.05, 'squared_error = 0.002\nsamples = 3\nvalue = 0.286'),
#  Text(0.9277238403451996, 0.05, 'squared_error = 0.007\nsamples = 27\nvalue = 0.396'),
#  Text(0.9309600862998921, 0.15, 'X[2] <= -0.441\nsquared_error = 0.007\nsamples = 109\nvalue = 0.458'),
#  Text(0.9298813376483279, 0.05, 'squared_error = 0.004\nsamples = 69\nvalue = 0.478'),
#  Text(0.9320388349514563, 0.05, 'squared_error = 0.01\nsamples = 40\nvalue = 0.425'),
#  Text(0.9374325782092773, 0.25, 'X[2] <= -0.441\nsquared_error = 0.005\nsamples = 263\nvalue = 0.476'),
#  Text(0.9352750809061489, 0.15, 'X[8] <= 0.585\nsquared_error = 0.002\nsamples = 121\nvalue = 0.494'),
#  Text(0.9341963322545846, 0.05, 'squared_error = 0.0\nsamples = 63\nvalue = 0.504'),
#  Text(0.9363538295577131, 0.05, 'squared_error = 0.003\nsamples = 58\nvalue = 0.484'),
#  Text(0.9395900755124056, 0.15, 'X[4] <= -0.251\nsquared_error = 0.007\nsamples = 142\nvalue = 0.461'),
#  Text(0.9385113268608414, 0.05, 'squared_error = 0.004\nsamples = 58\nvalue = 0.481'),
#  Text(0.9406688241639698, 0.05, 'squared_error = 0.008\nsamples = 84\nvalue = 0.447'),
#  Text(0.970873786407767, 0.55, 'X[11] <= 0.434\nsquared_error = 0.001\nsamples = 2910\nvalue = 0.498'),
#  Text(0.9565803667745415, 0.45, 'X[10] <= 0.209\nsquared_error = 0.007\nsamples = 140\nvalue = 0.445'),
#  Text(0.9503775620280475, 0.35, 'X[10] <= -0.125\nsquared_error = 0.002\nsamples = 37\nvalue = 0.315'),
#  Text(0.9460625674217907, 0.25, 'X[10] <= -0.227\nsquared_error = 0.0\nsamples = 21\nvalue = 0.285'),
#  Text(0.9439050701186623, 0.15, 'X[11] <= 0.408\nsquared_error = 0.0\nsamples = 9\nvalue = 0.265'),
#  Text(0.9428263214670982, 0.05, 'squared_error = 0.0\nsamples = 4\nvalue = 0.252'),
#  Text(0.9449838187702265, 0.05, 'squared_error = 0.0\nsamples = 5\nvalue = 0.275'),
#  Text(0.948220064724919, 0.15, 'X[11] <= 0.401\nsquared_error = 0.0\nsamples = 12\nvalue = 0.299'),
#  Text(0.9471413160733549, 0.05, 'squared_error = 0.0\nsamples = 2\nvalue = 0.276'),
#  Text(0.9492988133764833, 0.05, 'squared_error = 0.0\nsamples = 10\nvalue = 0.304'),
#  Text(0.9546925566343042, 0.25, 'X[10] <= 0.067\nsquared_error = 0.001\nsamples = 16\nvalue = 0.354'),
#  Text(0.9525350593311759, 0.15, 'X[10] <= -0.014\nsquared_error = 0.0\nsamples = 7\nvalue = 0.331'),
#  Text(0.9514563106796117, 0.05, 'squared_error = 0.0\nsamples = 5\nvalue = 0.325'),
#  Text(0.95361380798274, 0.05, 'squared_error = 0.0\nsamples = 2\nvalue = 0.345'),
#  Text(0.9568500539374326, 0.15, 'X[1] <= -0.005\nsquared_error = 0.0\nsamples = 9\nvalue = 0.372'),
#  Text(0.9557713052858684, 0.05, 'squared_error = 0.0\nsamples = 3\nvalue = 0.359'),
#  Text(0.9579288025889967, 0.05, 'squared_error = 0.0\nsamples = 6\nvalue = 0.378'),
#  Text(0.9627831715210357, 0.35, 'X[10] <= 0.24\nsquared_error = 0.001\nsamples = 103\nvalue = 0.492'),
#  Text(0.9600862998921251, 0.25, 'X[8] <= -0.271\nsquared_error = 0.0\nsamples = 2\nvalue = 0.414'),
#  Text(0.9590075512405609, 0.15, 'squared_error = 0.0\nsamples = 1\nvalue = 0.422'),
#  Text(0.9611650485436893, 0.15, 'squared_error = -0.0\nsamples = 1\nvalue = 0.405'),
#  Text(0.9654800431499461, 0.25, 'X[1] <= -0.005\nsquared_error = 0.001\nsamples = 101\nvalue = 0.493'),
#  Text(0.9633225458468176, 0.15, 'X[5] <= -0.393\nsquared_error = 0.0\nsamples = 51\nvalue = 0.503'),
#  Text(0.9622437971952535, 0.05, 'squared_error = -0.0\nsamples = 45\nvalue = 0.505'),
#  Text(0.9644012944983819, 0.05, 'squared_error = 0.0\nsamples = 6\nvalue = 0.489'),
#  Text(0.9676375404530745, 0.15, 'X[7] <= 0.795\nsquared_error = 0.001\nsamples = 50\nvalue = 0.484'),
#  Text(0.9665587918015103, 0.05, 'squared_error = 0.001\nsamples = 23\nvalue = 0.466'),
#  Text(0.9687162891046386, 0.05, 'squared_error = 0.0\nsamples = 27\nvalue = 0.499'),
#  Text(0.9851672060409924, 0.45, 'X[10] <= -0.004\nsquared_error = 0.0\nsamples = 2770\nvalue = 0.5'),
#  Text(0.9784250269687162, 0.35, 'X[2] <= -0.296\nsquared_error = 0.002\nsamples = 550\nvalue = 0.487'),
#  Text(0.9741100323624595, 0.25, 'X[5] <= -0.393\nsquared_error = 0.001\nsamples = 313\nvalue = 0.498'),
#  Text(0.9719525350593312, 0.15, 'X[0] <= -0.001\nsquared_error = 0.005\nsamples = 3\nvalue = 0.455'),
#  Text(0.970873786407767, 0.05, 'squared_error = 0.0\nsamples = 2\nvalue = 0.505'),
#  Text(0.9730312837108953, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = 0.356'),
#  Text(0.9762675296655879, 0.15, 'X[2] <= -0.441\nsquared_error = 0.001\nsamples = 310\nvalue = 0.499'),
#  Text(0.9751887810140237, 0.05, 'squared_error = 0.0\nsamples = 250\nvalue = 0.501'),
#  Text(0.9773462783171522, 0.05, 'squared_error = 0.001\nsamples = 60\nvalue = 0.491'),
#  Text(0.982740021574973, 0.25, 'X[2] <= 0.427\nsquared_error = 0.003\nsamples = 237\nvalue = 0.473'),
#  Text(0.9805825242718447, 0.15, 'X[10] <= -0.156\nsquared_error = 0.003\nsamples = 8\nvalue = 0.403'),
#  Text(0.9795037756202805, 0.05, 'squared_error = 0.003\nsamples = 6\nvalue = 0.382'),
#  Text(0.9816612729234089, 0.05, 'squared_error = 0.0\nsamples = 2\nvalue = 0.463'),
#  Text(0.9848975188781014, 0.15, 'X[7] <= 0.795\nsquared_error = 0.003\nsamples = 229\nvalue = 0.475'),
#  Text(0.9838187702265372, 0.05, 'squared_error = 0.003\nsamples = 208\nvalue = 0.479'),
#  Text(0.9859762675296656, 0.05, 'squared_error = 0.005\nsamples = 21\nvalue = 0.439'),
#  Text(0.9919093851132686, 0.35, 'X[10] <= 0.22\nsquared_error = 0.0\nsamples = 2220\nvalue = 0.504'),
#  Text(0.9881337648327939, 0.25, 'X[2] <= -0.151\nsquared_error = 0.0\nsamples = 269\nvalue = 0.498'),
#  Text(0.9870550161812298, 0.15, 'squared_error = -0.0\nsamples = 67\nvalue = 0.505'),
#  Text(0.9892125134843581, 0.15, 'X[2] <= 0.572\nsquared_error = 0.0\nsamples = 202\nvalue = 0.495'),
#  Text(0.9881337648327939, 0.05, 'squared_error = 0.001\nsamples = 14\nvalue = 0.466'),
#  Text(0.9902912621359223, 0.05, 'squared_error = 0.0\nsamples = 188\nvalue = 0.497'),
#  Text(0.9956850053937433, 0.25, 'X[5] <= -0.393\nsquared_error = 0.0\nsamples = 1951\nvalue = 0.504'),
#  Text(0.9935275080906149, 0.15, 'X[7] <= -0.763\nsquared_error = 0.0\nsamples = 830\nvalue = 0.505'),
#  Text(0.9924487594390508, 0.05, 'squared_error = 0.0\nsamples = 25\nvalue = 0.503'),
#  Text(0.9946062567421791, 0.05, 'squared_error = 0.0\nsamples = 805\nvalue = 0.505'),
#  Text(0.9978425026968716, 0.15, 'X[8] <= 0.559\nsquared_error = 0.0\nsamples = 1121\nvalue = 0.504'),
#  Text(0.9967637540453075, 0.05, 'squared_error = 0.0\nsamples = 1051\nvalue = 0.504'),
#  Text(0.9989212513484358, 0.05, 'squared_error = 0.0\nsamples = 70\nvalue = 0.503')]

# %%
dr.fit(x_test,y_test)
y_test_pred=dr.predict(x_test)

# %%
r2=r2_score(y_test,y_test_pred)
r2
# Out:
# 0.9982336252532468

# %%
Mean_Squared_Error=mean_squared_error(y_test,y_test_pred)
Mean_Squared_Error
# Out:
# 0.000515100921138393
